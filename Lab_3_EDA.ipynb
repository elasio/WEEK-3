# %% [markdown]
# ![](https://i.imgur.com/0AUxkXt.png)

# %% [markdown]
# # Lab 3 - From data to insights
#
# Before you explore the data, write down a short list of what you expect to see in the data: the distribution of key variables, the relationships between important pairs of them, and so on. Such a list is essentially a prediction based on your current understanding of the business.
#
# Now analyze the data. Make plots, do summaries, whatever is needed to see if it matches your expectations.
#
# Is there anything that doesn’t match? Anything that makes you go “That’s odd” or “That doesn’t make any sense.”?
#
# Zoom in and try to understand what in your business is making that weird thing show up in the data like that. This is the critical step.
#
# You may have just found an insight into the business and increased your understanding
#
#
# ## The data analysis checklist
#
# This checklist can be used as a guide during the process of a data analysis, or as a way to evaluate the quality of a reported data analysis.
#
# ### Answering the first questions
#
# 1. Did you define the metric for success before beginning?
# 2. Did you understand the context for the question and business application?
# 3. Did you consider whether the question could be answered with the available data?
#
# ### Cleaning the data
#
# 1. Did you identify the missing data?
# 2. Is each variable one column?
# 3. Do different data types appear in each table?
# 4. Did you try to identify any errors or miscoding of variables?
# 5. Did you check for outliers?
#
# ### Exploratory analysis
#
# 1. Did you make univariate plots (histogram, distplot, boxplot)?
# 2. Did you consider correlations between variables (scatterplot, jointplot, kde plot, correlation matrix)?
# 3. Did you check the units of all data points to make sure they are in the right range?
#
# ### Presentations
#
# 1. Did you lead with a brief, understandable to everyone of your problem?
# 2. Did you explain the data, describe the question of interest?
# 3. Did you make sure all legends and axes were legible from the back of the room?

# %% [markdown]
# ## Example - San Francisco city employee salary data
#
# One way to understand how a city government works is by looking at who it employs and how its employees are compensated. This data contains the names, job title, and compensation for San Francisco city employees on an annual basis from 2011 to 2014.
#
#
# ### Step 1 - Exploration Ideas
#
# 1. How have salaries changed over time between different groups of people?
# 2. How are base pay, overtime pay, and benefits allocated between different groups?
# 4. How is budget allocated based on different groups and responsibilities?
#
# ### Step 2 - Checking the data
#
# **Import tools set**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

sns.set_style("whitegrid")

# %% [markdown]
# **Import data**

# %%
# Fill the blanks
# Load the data from https://ml101-khanhnguyen.s3-ap-southeast-1.amazonaws.com/devc/Salaries.csv into `sal` variable
sal=pd.read_csv('https://ml101-khanhnguyen.s3-ap-southeast-1.amazonaws.com/devc/Salaries.csv')

# %% [markdown]
# **Check out head(), sample(), info(), describe()**

# %%
sal.head()
# Out:
#    Id       EmployeeName  ...         Agency  Status
# 0   1     NATHANIEL FORD  ...  San Francisco     NaN
# 1   2       GARY JIMENEZ  ...  San Francisco     NaN
# 2   3     ALBERT PARDINI  ...  San Francisco     NaN
# 3   4  CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4   5    PATRICK GARDNER  ...  San Francisco     NaN
#
# [5 rows x 13 columns]

# %%
# Fix the error
sal.sample(5)
# Out:
#             Id              EmployeeName  ...         Agency  Status
# 14964    14965               KULDIP KAUR  ...  San Francisco     NaN
# 117615  117616              Miguel Prado  ...  San Francisco     NaN
# 111647  111648           Thomas W Carter  ...  San Francisco     NaN
# 120608  120609         Margaret M Miller  ...  San Francisco     NaN
# 71823    71824  Rosa-Leah Martinez-Davis  ...  San Francisco     NaN
#
# [5 rows x 13 columns]

# %%
# Fix the error
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
# Fix the error
sal.describe()
# Out:
#                   Id        BasePay  ...  Notes  Status
# count  148654.000000  148045.000000  ...    0.0     0.0
# mean    74327.500000   66325.448841  ...    NaN     NaN
# std     42912.857795   42764.635495  ...    NaN     NaN
# min         1.000000    -166.010000  ...    NaN     NaN
# 25%     37164.250000   33588.200000  ...    NaN     NaN
# 50%     74327.500000   65007.450000  ...    NaN     NaN
# 75%    111490.750000   94691.050000  ...    NaN     NaN
# max    148654.000000  319275.010000  ...    NaN     NaN
#
# [8 rows x 10 columns]

# %% [markdown]
# ### Step 3 - Cleaning the data
#
# Few of useful data cleaning functions:
#
# * `s.astype('category')` # This will convert the datatype of the series to float *Please note that "s" here is a Pandas Series
#
# * `s.replace(1,'one')` # This will replace all values equal to 1 with 'one'
#
# * `s.replace([1,3],['one','three'])` # This will replace all 1 with 'one' and 3 with 'three'
#
# * `data.rename(columns=lambda x: x + 1)` # Mass renaming of columns
#
# * `data.rename(columns={'oldname': 'new name'})` # Selective renaming
#
# * `data.set_index('column_one')` #  This will change the index
#
# * `data.rename(index=lambda x: x + 1)` # Mass renaming of index
#
# * `data.dropna()` # Remove missing values
#
# * `data.fillna(x)` #  This will replaces all null values with x
#
# * `s.fillna(s.mean())` # This will replace all null values with the mean (mean can be replaced with almost any function from the below section) :
#
# * `data.corr()` # This will return the correlation between columns in a DataFrame
#
# * `data.count()` # This will return the number of non-null values in each DataFrame column
#
# * `data.max()` # This will return the highest value in each column
#
# * `data.min()` # This will return the lowest value in each column
#
# * `data.median()` # This will return the median of each column
#
# * `data.std()` # This will returns the standard deviation of each column

# %% [markdown]
# **Check duplication in columns in which the data must be unique**

# %%
# Id must be unique
# So the number of unique values must be equal the number of rows
# Fill the blanks
sal['Id'].nunique() == len(sal)
# Out:
# True

# %% [markdown]
# **Change the type to category**

# %%
sal['Id'] = sal['Id'].astype('category')

# Change Year to be a categorical variable too
# Your code here
sal['Year']=sal['Year'].astype('category')

# %% [markdown]
# **Drop unnecessary columns**

# %%
# Look at the info() again, which columns you can drop immediately?
# Fill the blanks
sal.drop(columns=['Notes', 'Status'], inplace=True)

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 11 columns):
# Id                  148654 non-null category
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null category
# Agency              148654 non-null object
# dtypes: category(2), float64(6), object(3)
# memory usage: 17.1+ MB

# %%
sal.head()
# Out:
#   Id       EmployeeName  ...  Year         Agency
# 0  1     NATHANIEL FORD  ...  2011  San Francisco
# 1  2       GARY JIMENEZ  ...  2011  San Francisco
# 2  3     ALBERT PARDINI  ...  2011  San Francisco
# 3  4  CHRISTOPHER CHONG  ...  2011  San Francisco
# 4  5    PATRICK GARDNER  ...  2011  San Francisco
#
# [5 rows x 11 columns]

# %%
# Are there any other columns that don't bring us much information?
# Drop them coldbloodedly
# Your code here
sal.drop(columns=['Agency'],inplace=True)

# %%
# Check again with info()
# Your code here
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 10 columns):
# Id                  148654 non-null category
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null category
# dtypes: category(2), float64(6), object(2)
# memory usage: 15.9+ MB

# %% [markdown]
# **Check for NaN values**

# %%
# Fill the blank
sal.isna().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay               609
# OvertimePay             4
# OtherPay                4
# Benefits            36163
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %% [markdown]
# **Examine few examples of NaN values**

# %%
# List all NaN values of OtherPay
# Fill the blanks
sal[sal['OtherPay'].isnull()]
# Out:
#             Id  EmployeeName      JobTitle  ...  TotalPay  TotalPayBenefits  Year
# 148646  148647  Not provided  Not provided  ...       0.0               0.0  2014
# 148650  148651  Not provided  Not provided  ...       0.0               0.0  2014
# 148651  148652  Not provided  Not provided  ...       0.0               0.0  2014
# 148652  148653  Not provided  Not provided  ...       0.0               0.0  2014
#
# [4 rows x 10 columns]

# %% [markdown]
# **Drop missing values of OtherPay and OvertimePay**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 10 columns):
# Id                  148654 non-null category
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null category
# dtypes: category(2), float64(6), object(2)
# memory usage: 15.9+ MB

# %%
# Option 1
# sal.drop(labels=[148646, 148650, 148651, 148652], axis=0)

# Something cooler
# Solution: Select data that OtherPay is not null and assign it to the dataframe 'sal'
# Your code here
sal=sal[~sal['OtherPay'].isnull()]
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148650 entries, 0 to 148653
# Data columns (total 10 columns):
# Id                  148650 non-null category
# EmployeeName        148650 non-null object
# JobTitle            148650 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148650 non-null float64
# TotalPayBenefits    148650 non-null float64
# Year                148650 non-null category
# dtypes: category(2), float64(6), object(2)
# memory usage: 17.1+ MB

# %% [markdown]
# **Analize missing values of BasePay and Benefits**

# %%
# Select 5 sample of data that BasePay is null
# Your code here

sal[sal['BasePay'].isnull()].sample(5)
# Out:
#             Id         EmployeeName  ... TotalPayBenefits  Year
# 106835  106836        Thomas E Horn  ...          7959.18  2013
# 109522  109523    Maria E Creighton  ...          1524.36  2013
# 106896  106897    Marlene  Saritzky  ...          7959.18  2013
# 108769  108770         Lihuang  Wan  ...          3008.45  2013
# 109237  109238  Jocelyn T Feliciano  ...          2084.71  2013
#
# [5 rows x 10 columns]

# %% [markdown]
# **For BasePay and Benefits, it is clear that NaN values are zeroes (from TotalPay and TotalPayBenefits).**
#
# **So, simply fill NaN values with 0**

# %%
# Fill the blanks
sal['Benefits'].fillna(value=0, inplace=True)
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148650 entries, 0 to 148653
# Data columns (total 10 columns):
# Id                  148650 non-null category
# EmployeeName        148650 non-null object
# JobTitle            148650 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            148650 non-null float64
# TotalPay            148650 non-null float64
# TotalPayBenefits    148650 non-null float64
# Year                148650 non-null category
# dtypes: category(2), float64(6), object(2)
# memory usage: 17.1+ MB

# %%
sal.isna().sum()
# Out:
# Id                    0
# EmployeeName          0
# JobTitle              0
# BasePay             605
# OvertimePay           0
# OtherPay              0
# Benefits              0
# TotalPay              0
# TotalPayBenefits      0
# Year                  0
# dtype: int64

# %%
# Fill the blanks
sal['BasePay'].fillna(value=0,inplace=True)
sal
# Out:
#             Id            EmployeeName  ... TotalPayBenefits  Year
# 0            1          NATHANIEL FORD  ...        567595.43  2011
# 1            2            GARY JIMENEZ  ...        538909.28  2011
# 2            3          ALBERT PARDINI  ...        335279.91  2011
# 3            4       CHRISTOPHER CHONG  ...        332343.61  2011
# 4            5         PATRICK GARDNER  ...        326373.19  2011
# 5            6          DAVID SULLIVAN  ...        316285.74  2011
# 6            7               ALSON LEE  ...        315981.05  2011
# 7            8           DAVID KUSHNER  ...        307899.46  2011
# 8            9          MICHAEL MORRIS  ...        303427.55  2011
# 9           10      JOANNE HAYES-WHITE  ...        302377.73  2011
# 10          11           ARTHUR KENNEY  ...        299494.17  2011
# 11          12        PATRICIA JACKSON  ...        297608.92  2011
# 12          13       EDWARD HARRINGTON  ...        294580.02  2011
# 13          14             JOHN MARTIN  ...        292671.62  2011
# 14          15          DAVID FRANKLIN  ...        286347.05  2011
# 15          16         RICHARD CORRIEA  ...        286213.86  2011
# 16          17                AMY HART  ...        284720.43  2011
# 17          18          SEBASTIAN WONG  ...        278569.21  2011
# 18          19              MARTY ROSS  ...        276434.22  2011
# 19          20           ELLEN MOFFATT  ...        274550.25  2011
# 20          21              VENUS AZAR  ...        274190.27  2011
# 21          22            JUDY MELINEK  ...        273771.21  2011
# 22          23           GEORGE GARCIA  ...        273702.71  2011
# 23          24           VICTOR WYRSCH  ...        270672.63  2011
# 24          25         JOSEPH DRISCOLL  ...        270324.91  2011
# 25          26            GREGORY SUHR  ...        267992.59  2011
# 26          27             JOHN HANLEY  ...        265784.56  2011
# 27          28          RAYMOND GUZMAN  ...        265463.46  2011
# 28          29          DENISE SCHMITT  ...        264074.60  2011
# 29          30           MONICA FIELDS  ...        261366.14  2011
# ...        ...                     ...  ...              ...   ...
# 148620  148621         India C Sabater  ...            15.66  2014
# 148621  148622          Kenneth Mackey  ...            15.35  2014
# 148622  148623      Jacqueline Hubbard  ...            13.77  2014
# 148623  148624         Deborah B Honig  ...            13.48  2014
# 148624  148625      Lorraine Rosenthal  ...            12.89  2014
# 148625  148626         Renato C Gurion  ...             7.24  2014
# 148626  148627           Paulet Gaines  ...             0.00  2014
# 148627  148628        Brett A Lundberg  ...             0.00  2014
# 148628  148629          Mark W Mcclure  ...             0.00  2014
# 148629  148630       Elizabeth Iniguez  ...             0.00  2014
# 148630  148631            Randy J Keys  ...             0.00  2014
# 148631  148632         Andre M Johnson  ...             0.00  2014
# 148632  148633  Sharon D Owens-Webster  ...             0.00  2014
# 148633  148634        Edward Ferdinand  ...             0.00  2014
# 148634  148635          David M Turner  ...             0.00  2014
# 148635  148636     James S Kibblewhite  ...             0.00  2014
# 148636  148637           Andrew J Enzi  ...             0.00  2014
# 148637  148638        Kadeshra D Green  ...             0.00  2014
# 148638  148639    Lennard B Hutchinson  ...             0.00  2014
# 148639  148640       Richard A Talbert  ...             0.00  2014
# 148640  148641      Charlene D Mccully  ...             0.00  2014
# 148641  148642   Raphael Marquis Goins  ...             0.00  2014
# 148642  148643       Dominic C Marquez  ...             0.00  2014
# 148643  148644              Kim Brewer  ...             0.00  2014
# 148644  148645            Randy D Winn  ...             0.00  2014
# 148645  148646        Carolyn A Wilson  ...             0.00  2014
# 148647  148648          Joann Anderson  ...             0.00  2014
# 148648  148649             Leon Walker  ...             0.00  2014
# 148649  148650           Roy I Tillery  ...             0.00  2014
# 148653  148654               Joe Lopez  ...          -618.13  2014
#
# [148650 rows x 10 columns]

# %%
# Let check for NaN values again
# Your code here

sal.isna().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# dtype: int64

# %% [markdown]
# **Min values of some payments are negative. Let's check it out**

# %%
# Select data that has negative TotalPay or TotalPayBenefits
sal[(sal['TotalPayBenefits']<0) | (sal['TotalPay']<0)]
# Out:
#             Id      EmployeeName  ... TotalPayBenefits  Year
# 110528  110529  Timothy E Gibson  ...            -2.73  2013
# 110529  110530    Mark E Laherty  ...            -8.20  2013
# 110530  110531     David P Kucia  ...           -33.89  2013
# 148653  148654         Joe Lopez  ...          -618.13  2014
#
# [4 rows x 10 columns]

# %% [markdown]
# **There are only 4 of them, we can safely drop these data**

# %%
# Your code here
sal=sal[(sal['TotalPayBenefits']>=0) & (sal['TotalPay']>=0)]
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148646 entries, 0 to 148649
# Data columns (total 10 columns):
# Id                  148646 non-null category
# EmployeeName        148646 non-null object
# JobTitle            148646 non-null object
# BasePay             148646 non-null float64
# OvertimePay         148646 non-null float64
# OtherPay            148646 non-null float64
# Benefits            148646 non-null float64
# TotalPay            148646 non-null float64
# TotalPayBenefits    148646 non-null float64
# Year                148646 non-null category
# dtypes: category(2), float64(6), object(2)
# memory usage: 17.0+ MB

# %% [markdown]
# **Identify any errors or miscoding of variables**

# %%
# Check the unique values of Year
# Your code here
sal['Year'].unique()
# Out:
# [2011, 2012, 2013, 2014]
# Categories (4, int64): [2011, 2012, 2013, 2014]

# %% [markdown]
# Check duplication

# %%
# Apply strip() on EmployeeName and Jobtitle 
# to remove all the leading and trailing spaces
# Fill the blanks
sal['EmployeeName'] = sal['EmployeeName'].str.strip()
sal['JobTitle'] = sal['JobTitle'].str.strip()
sal.head()
# Out:
#   Id       EmployeeName  ... TotalPayBenefits  Year
# 0  1     NATHANIEL FORD  ...        567595.43  2011
# 1  2       GARY JIMENEZ  ...        538909.28  2011
# 2  3     ALBERT PARDINI  ...        335279.91  2011
# 3  4  CHRISTOPHER CHONG  ...        332343.61  2011
# 4  5    PATRICK GARDNER  ...        326373.19  2011
#
# [5 rows x 10 columns]

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148646 entries, 0 to 148649
# Data columns (total 10 columns):
# Id                  148646 non-null category
# EmployeeName        148646 non-null object
# JobTitle            148646 non-null object
# BasePay             148646 non-null float64
# OvertimePay         148646 non-null float64
# OtherPay            148646 non-null float64
# Benefits            148646 non-null float64
# TotalPay            148646 non-null float64
# TotalPayBenefits    148646 non-null float64
# Year                148646 non-null category
# dtypes: category(2), float64(6), object(2)
# memory usage: 17.0+ MB

# %%
# Check the number of unique value of EmployeeName
sal['EmployeeName'].nunique()
# Out:
# 110806

# %%
# Check the number of unique value of EmployeeName in lower case
# Fill the blanks
sal['EmployeeName'].str.lower().nunique()
# Out:
# 80455

# %%
# Do the same with JobTitle
# Fill the blank
print(sal['JobTitle'].nunique())
print(sal['JobTitle'].str.lower().nunique())
# Out:
# 2158
# 1636

# %%
# Select the most common name
# Something wrong, fix the error
names = sal['EmployeeName'].str.lower().value_counts()
sample = names[names > 1].head(1).index
sal[sal['EmployeeName'].str.lower().isin(sample)]
# Out:
#             Id EmployeeName  ... TotalPayBenefits  Year
# 3824      3825    KEVIN LEE  ...        132837.90  2011
# 4036      4037    KEVIN LEE  ...        131494.88  2011
# 5279      5280    KEVIN LEE  ...        122818.61  2011
# 13169    13170    KEVIN LEE  ...         84302.61  2011
# 13419    13420    KEVIN LEE  ...         83560.00  2011
# 15312    15313    KEVIN LEE  ...         76786.31  2011
# 17163    17164    KEVIN LEE  ...         70955.55  2011
# 17646    17647    KEVIN LEE  ...         69393.44  2011
# 27053    27054    KEVIN LEE  ...         37275.54  2011
# 39715    39716    Kevin Lee  ...        183609.94  2012
# 40570    40571    Kevin Lee  ...        175633.29  2012
# 42510    42511    Kevin Lee  ...        161602.46  2012
# 49270    49271    Kevin Lee  ...        122062.61  2012
# 49439    49440    Kevin Lee  ...        121389.80  2012
# 50123    50124    Kevin Lee  ...        118592.59  2012
# 52233    52234    Kevin Lee  ...        109368.11  2012
# 53931    53932    Kevin Lee  ...        103765.17  2012
# 55119    55120    Kevin Lee  ...         99590.92  2012
# 112385  112386    Kevin Lee  ...        215598.07  2014
# 123141  123142    Kevin Lee  ...        126728.64  2014
# 124165  124166    Kevin Lee  ...        121525.34  2014
# 124658  124659    Kevin Lee  ...        119020.23  2014
#
# [22 rows x 10 columns]

# %% [markdown]
# *The names are duplicated because the data describes one person in different years or just because there are people who have same name. It's ok so we only need to uppercase all of the name to eliminate case sensitive.*
#
# *But there are definitely some duplication of Job Title, example `Police Officer 3` and `POLICE OFFICER III`*

# %%
# Replace Name and Job Title with its uppercase
# Fill the blanks
sal['EmployeeName'] = sal['EmployeeName'].str.upper()
sal['JobTitle'] = sal['JobTitle'].str.upper()

# %%
# Write a regular expression to select JobTitle that ends with a digit
# Fill the blank
sal['JobTitle'][sal['JobTitle'].str.contains('\d$', regex=True)].value_counts()
# Out:
# POLICE OFFICER 3                 2418
# POLICE OFFICER 2                 1141
# SERGEANT 3                       1047
# LIBRARIAN 1                       530
# HEALTH WORKER 3                   438
# HEALTH WORKER 2                   415
# INSPECTOR 3                       318
# LIEUTENANT 3                      303
# SECRETARY 2                       301
# LIBRARY TECHNICAL ASSISTANT 1     237
# LEGAL SECRETARY 1                 184
# EXECUTIVE SECRETARY 1             184
# EXECUTIVE SECRETARY 2             178
# HEALTH CARE BILLING CLERK 2       177
# PLANNER 3                         174
# LIBRARIAN 2                       174
# EMPLOYMENT & TRAINING SPEC 3      167
# HEALTH PROGRAM COORDINATOR 3      167
# HEALTH WORKER 1                   163
# SR. COMMUNITY DEVL SPC 1          148
# GENERAL LABORER SUPERVISOR 1      137
# SERGEANT 2                        131
# IS ADMINISTRATOR 2                113
# COMMUNICATIONS DISPATCHER 1       106
# PLANNER 2                         106
# CAPTAIN 3                         101
# ENGINEERING ASSOCIATE 1            99
# CONTRACT COMPLIANCE OFFICER 1      96
# LIBRARY TECHNICAL ASSISTANT 2      96
# COMMUNICATIONS DISPATCHER 2        88
#                                  ...
# EMPLOYMENT & TRAINING SPEC 6        3
# SPECIAL ASSISTANT 21                3
# PLUMBER SUPERVISOR 2                3
# POWER PLANT SUPERVISOR 1            3
# SPECIAL ASSISTANT 15                3
# SHEET METAL WRK SUPERVISOR 2        3
# PAINTER SUPERVISOR 2                3
# SPECIAL ASSISTANT 14                3
# ROOFER SUPERVISOR 1                 3
# WHARFINGER 1                        3
# ORTHOPEDIC TECHNICIAN 2             3
# ASST DIR OF CLINICAL SVCS 1         3
# BD/COMM SECRETARY 3                 3
# ASPHALT PLANT SUPERVISOR 1          3
# ELECTRIC MOTOR REPAIR SPRV 1        3
# ORNAMENTAL IRON WRK SPRV 1          3
# SPECIALIST IN AGING 2               3
# ORTHOPEDIC TECHNICIAN 1             3
# SPECIAL ASSISTANT 16                2
# WATER METER SHOP SUPERVISOR 1       2
# CEMENT FINISHER SUPERVISOR 2        2
# ENVIRONMENTAL HLTH TECH 2           2
# GLAZIER SUPERVISOR 1                2
# TRANSIT PAINT SHOP SPRV1            2
# SPECIAL ASSISTANT 11                2
# ASST DIR CLINICAL SVCS 2            1
# SPECIAL ASSISTANT 8                 1
# SPECIAL ASSISTANT 18                1
# CASHIER 3                           1
# SPECIAL ASSISTANT 13                1
# Name: JobTitle, Length: 166, dtype: int64

# %%
# Write a regex that count all JobTitle start with POLICE OFFICER
# Fill the blank
sal['JobTitle'][sal['JobTitle'].str.contains('^POLICE OFFICER', regex=True)].value_counts()
# Out:
# POLICE OFFICER 3      2418
# POLICE OFFICER        1476
# POLICE OFFICER 2      1141
# POLICE OFFICER III     779
# POLICE OFFICER I       467
# POLICE OFFICER II      361
# Name: JobTitle, dtype: int64

# %% [markdown]
# There are discrepancies on how those `JobTitle` are represented. For instance: `POLICE OFFICER II` is `POLICE OFFICER 2` and those should be treated equally.
#
# We'll modify this feature accordingly by transforming all the Roman numbers  to our every day numbers.

# %%
# This is a simple function to transform roman number
def transform_roman(s):
    d = {'I':1, 'II':2, 'III':3, 'IV':4, 'V':5, 'VI':6, 'VII':7, 'VIII':8, 'IX':9, 'X':10, 
        'XI':11, 'XII':12, 'XIII':13, 'XIV':14, 'XV':15, 'XVI':16, 'XVII':17, 'XVIII':18, 'XIX':19, 'XX':20}
    
    s_split = s.split()
    if s_split[-1] in d.keys():
        s_split[-1] = str(d[s_split[-1]])
    return ' '.join(s_split)

# Test it out
transform_roman('POLICE OFFICER III')
# Out:
# 'POLICE OFFICER 3'

# %%
# Apply the function above to the column JobTitle
# Fill the blank
sal['JobTitle'] = sal['JobTitle'].apply(transform_roman)

# %%
sal['JobTitle'][sal['JobTitle'].str.contains('^POLICE OFFICER', regex=True)].value_counts()
# Out:
# POLICE OFFICER 3    3197
# POLICE OFFICER 2    1502
# POLICE OFFICER      1476
# POLICE OFFICER 1     467
# Name: JobTitle, dtype: int64

# %% [markdown]
# ### Step 4 - EDA

# %% [markdown]
# **Plot categorical data**

# %%
sns.countplot(x='Year', data=sal)
# What can you tell by looking at this?

# %% [markdown]
# **Top 5 common job titles**

# %%
# Fill the blanks 
sal['JobTitle'].value_counts().head().plot(kind='barh')

# %% [markdown]
# **Distribution of numerical data**

# %%
# Run this
sns.distplot(sal['TotalPayBenefits'],bins=5)

# %%
# Histogram is sensitive with the bins, try some examples to prove that
plt.hist(sal['TotalPayBenefits'], bins=5)
plt.show()

# %%
# Plot these diagrams in a dashboard with two rows and two columns

f, axes = plt.subplots(2, 2, figsize=(12, 6))

# Your code here

sns.distplot(sal['BasePay'], ax=axes[0,0])
sns.distplot(sal['OvertimePay'], ax=axes[0,1])
sns.distplot(sal['OtherPay'], ax=axes[1,0])
sns.distplot(sal['Benefits'], ax=axes[1,1])

plt.show()

# %%
# Plot these diagrams in a dashboard with one rows and two columns
# sns.distplot(sal['TotalPay'])
# sns.distplot(sal['TotalPayBenefits'])

f, axes = plt.subplots(1, 2, figsize=(12, 6))

# Your code here# 
sns.distplot(sal['TotalPay'],ax=axes[0])
sns.distplot(sal['TotalPayBenefits'],ax=axes[1])

plt.show()

# %% [markdown]
# **Analize richest people**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148646 entries, 0 to 148649
# Data columns (total 11 columns):
# Id                  148646 non-null category
# EmployeeName        148646 non-null object
# JobTitle            148646 non-null object
# BasePay             148646 non-null float64
# OvertimePay         148646 non-null float64
# OtherPay            148646 non-null float64
# Benefits            148646 non-null float64
# TotalPay            148646 non-null float64
# TotalPayBenefits    148646 non-null float64
# Year                148646 non-null category
# IncomeType          148646 non-null object
# dtypes: category(2), float64(6), object(3)
# memory usage: 23.2+ MB

# %%
# Select people that have TotalPayBenefit greater than $300k
# Your code here
sal[sal['TotalPayBenefits']>300000]
# Out:
#             Id          EmployeeName  ...  Year   IncomeType
# 0            1        NATHANIEL FORD  ...  2011  Millionaire
# 1            2          GARY JIMENEZ  ...  2011  Millionaire
# 2            3        ALBERT PARDINI  ...  2011  Millionaire
# 3            4     CHRISTOPHER CHONG  ...  2011  Millionaire
# 4            5       PATRICK GARDNER  ...  2011  Millionaire
# 5            6        DAVID SULLIVAN  ...  2011  Millionaire
# 6            7             ALSON LEE  ...  2011  Millionaire
# 7            8         DAVID KUSHNER  ...  2011  Millionaire
# 8            9        MICHAEL MORRIS  ...  2011  Millionaire
# 9           10    JOANNE HAYES-WHITE  ...  2011  Millionaire
# 36159    36160        GARY ALTENBERG  ...  2012  Millionaire
# 36160    36161          GREGORY SUHR  ...  2012  Millionaire
# 36161    36162            KHOA TRINH  ...  2012  Millionaire
# 36162    36163    JOANNE HAYES-WHITE  ...  2012  Millionaire
# 36163    36164     FREDERICK BINKLEY  ...  2012  Millionaire
# 36164    36165              AMY HART  ...  2012  Millionaire
# 36165    36166        EDWARD REISKIN  ...  2012  Millionaire
# 36166    36167           JOHN MARTIN  ...  2012  Millionaire
# 36167    36168         JOHN GOLDBERG  ...  2012  Millionaire
# 36168    36169        DAVID FRANKLIN  ...  2012  Millionaire
# 36169    36170          BRENDAN WARD  ...  2012  Millionaire
# 36170    36171            SAMSON LAI  ...  2012  Millionaire
# 36171    36172      RUDY CASTELLANOS  ...  2012  Millionaire
# 36172    36173            MARTY ROSS  ...  2012  Millionaire
# 36173    36174          MARK KEARNEY  ...  2012  Millionaire
# 36174    36175           LEDA ROZIER  ...  2012  Millionaire
# 36175    36176         ELLEN MOFFATT  ...  2012  Millionaire
# 36176    36177        RAYMOND GUZMAN  ...  2012  Millionaire
# 36177    36178     EDWARD HARRINGTON  ...  2012  Millionaire
# 36178    36179          JUDY MELINEK  ...  2012  Millionaire
# ...        ...                   ...  ...   ...          ...
# 110592  110593    RAEMONA E WILLIAMS  ...  2014  Millionaire
# 110593  110594       ROMELIA C SCOTT  ...  2014  Millionaire
# 110594  110595      GREGORY CORRALES  ...  2014  Millionaire
# 110595  110596         GEORGE FOURAS  ...  2014  Millionaire
# 110596  110597           EMILIO CRUZ  ...  2014  Millionaire
# 110597  110598         DALE C CARNES  ...  2014  Millionaire
# 110598  110599        TOMAS J ARAGON  ...  2014  Millionaire
# 110599  110600       LESLIE A DUBBIN  ...  2014  Millionaire
# 110600  110601         CHARLES CRANE  ...  2014  Millionaire
# 110601  110602         MICHIE L WONG  ...  2014  Millionaire
# 110602  110603         IVAR C SATERO  ...  2014  Millionaire
# 110603  110604         ANA C SAMPERA  ...  2014  Millionaire
# 110604  110605         JOHN A HICKEY  ...  2014  Millionaire
# 110605  110606       DENISE L NEWMAN  ...  2014  Millionaire
# 110606  110607     NELA C PONFERRADA  ...  2014  Millionaire
# 110607  110608         JOHN S RAHAIM  ...  2014  Millionaire
# 110608  110609         TERENCE E WOO  ...  2014  Millionaire
# 110609  110610      DENNIS J HERRERA  ...  2014  Millionaire
# 110610  110611       GERALD K MANSUR  ...  2014  Millionaire
# 110611  110612    MICHAEL I THOMPSON  ...  2014  Millionaire
# 110612  110613            REX J HALE  ...  2014  Millionaire
# 110613  110614             ALBERT YU  ...  2014  Millionaire
# 110614  110615      SHANNON S HEINTZ  ...  2014  Millionaire
# 110615  110616         SAMUEL ROMERO  ...  2014  Millionaire
# 110616  110617        ALEXANDER CHEN  ...  2014  Millionaire
# 110617  110618           JAY K DOWKE  ...  2014  Millionaire
# 110618  110619          EDWARD Y CHU  ...  2014  Millionaire
# 110619  110620  MATTHEW J MCNAUGHTON  ...  2014  Millionaire
# 110620  110621    MADONNA P VALENCIA  ...  2014  Millionaire
# 110621  110622      ROSS B MIRKARIMI  ...  2014  Millionaire
#
# [289 rows x 11 columns]

# %%
def split_income_type(n):
    if n < 1000:
        return 'Retired'
    elif n < 50000:
        return 'Low Income'
    elif n < 150000:
        return 'Midrange'
    elif n < 250000:
        return 'High Income'
    else:
        return 'Millionaire'

# %%
# Apply the function above to create a new column name IncomeType from TotalPayBenefits
# Fill the blank
sal['IncomeType'] = sal['TotalPayBenefits'].apply(split_income_type)
# Out:
#             Id            EmployeeName  ...  Year   IncomeType
# 0            1          NATHANIEL FORD  ...  2011  Millionaire
# 1            2            GARY JIMENEZ  ...  2011  Millionaire
# 2            3          ALBERT PARDINI  ...  2011  Millionaire
# 3            4       CHRISTOPHER CHONG  ...  2011  Millionaire
# 4            5         PATRICK GARDNER  ...  2011  Millionaire
# 5            6          DAVID SULLIVAN  ...  2011  Millionaire
# 6            7               ALSON LEE  ...  2011  Millionaire
# 7            8           DAVID KUSHNER  ...  2011  Millionaire
# 8            9          MICHAEL MORRIS  ...  2011  Millionaire
# 9           10      JOANNE HAYES-WHITE  ...  2011  Millionaire
# 10          11           ARTHUR KENNEY  ...  2011  Millionaire
# 11          12        PATRICIA JACKSON  ...  2011  Millionaire
# 12          13       EDWARD HARRINGTON  ...  2011  Millionaire
# 13          14             JOHN MARTIN  ...  2011  Millionaire
# 14          15          DAVID FRANKLIN  ...  2011  Millionaire
# 15          16         RICHARD CORRIEA  ...  2011  Millionaire
# 16          17                AMY HART  ...  2011  Millionaire
# 17          18          SEBASTIAN WONG  ...  2011  Millionaire
# 18          19              MARTY ROSS  ...  2011  Millionaire
# 19          20           ELLEN MOFFATT  ...  2011  Millionaire
# 20          21              VENUS AZAR  ...  2011  Millionaire
# 21          22            JUDY MELINEK  ...  2011  Millionaire
# 22          23           GEORGE GARCIA  ...  2011  Millionaire
# 23          24           VICTOR WYRSCH  ...  2011  Millionaire
# 24          25         JOSEPH DRISCOLL  ...  2011  Millionaire
# 25          26            GREGORY SUHR  ...  2011  Millionaire
# 26          27             JOHN HANLEY  ...  2011  Millionaire
# 27          28          RAYMOND GUZMAN  ...  2011  Millionaire
# 28          29          DENISE SCHMITT  ...  2011  Millionaire
# 29          30           MONICA FIELDS  ...  2011  Millionaire
# ...        ...                     ...  ...   ...          ...
# 148619  148620           IAN V CAMERON  ...  2014      Retired
# 148620  148621         INDIA C SABATER  ...  2014      Retired
# 148621  148622          KENNETH MACKEY  ...  2014      Retired
# 148622  148623      JACQUELINE HUBBARD  ...  2014      Retired
# 148623  148624         DEBORAH B HONIG  ...  2014      Retired
# 148624  148625      LORRAINE ROSENTHAL  ...  2014      Retired
# 148625  148626         RENATO C GURION  ...  2014      Retired
# 148626  148627           PAULET GAINES  ...  2014      Retired
# 148627  148628        BRETT A LUNDBERG  ...  2014      Retired
# 148628  148629          MARK W MCCLURE  ...  2014      Retired
# 148629  148630       ELIZABETH INIGUEZ  ...  2014      Retired
# 148630  148631            RANDY J KEYS  ...  2014      Retired
# 148631  148632         ANDRE M JOHNSON  ...  2014      Retired
# 148632  148633  SHARON D OWENS-WEBSTER  ...  2014      Retired
# 148633  148634        EDWARD FERDINAND  ...  2014      Retired
# 148634  148635          DAVID M TURNER  ...  2014      Retired
# 148635  148636     JAMES S KIBBLEWHITE  ...  2014      Retired
# 148636  148637           ANDREW J ENZI  ...  2014      Retired
# 148637  148638        KADESHRA D GREEN  ...  2014      Retired
# 148638  148639    LENNARD B HUTCHINSON  ...  2014      Retired
# 148639  148640       RICHARD A TALBERT  ...  2014      Retired
# 148640  148641      CHARLENE D MCCULLY  ...  2014      Retired
# 148641  148642   RAPHAEL MARQUIS GOINS  ...  2014      Retired
# 148642  148643       DOMINIC C MARQUEZ  ...  2014      Retired
# 148643  148644              KIM BREWER  ...  2014      Retired
# 148644  148645            RANDY D WINN  ...  2014      Retired
# 148645  148646        CAROLYN A WILSON  ...  2014      Retired
# 148647  148648          JOANN ANDERSON  ...  2014      Retired
# 148648  148649             LEON WALKER  ...  2014      Retired
# 148649  148650           ROY I TILLERY  ...  2014      Retired
#
# [148646 rows x 11 columns]

# %%
sns.countplot(sal['IncomeType'])
# What can you tell?

# %%
# Pie chart
labels = []
sizes = []
explode = []

labels = sal['IncomeType'].value_counts().index
for index, size in enumerate(sal['IncomeType'].value_counts()):
    sizes.append(size)
    if labels[index]=='Millionaire':
        explode.append(0.2)
    else: # add high income too?
        explode.append(0)
 
f, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=45)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
sal.head()
# Out:
#   Id       EmployeeName  ...  Year   IncomeType
# 0  1     NATHANIEL FORD  ...  2011  Millionaire
# 1  2       GARY JIMENEZ  ...  2011  Millionaire
# 2  3     ALBERT PARDINI  ...  2011  Millionaire
# 3  4  CHRISTOPHER CHONG  ...  2011  Millionaire
# 4  5    PATRICK GARDNER  ...  2011  Millionaire
#
# [5 rows x 11 columns]

# %%
# What is the top 10 Job Title of Millionaire
# Fill the blank
millionare_jobs = sal[sal['IncomeType']=='Millionaire'].groupby('JobTitle').mean()
millionare_jobs.sort_values(by=['TotalPayBenefits'], ascending=False)['TotalPayBenefits'].head(10).plot(kind='barh')

# %%
# Find the name of 10 richest man
# Your code here
rich_man=sal.sort_values(by='TotalPayBenefits',ascending=False).head(10)[['EmployeeName','TotalPayBenefits','Year']]
rich_man.plot(x='EmployeeName',y='TotalPayBenefits',kind='barh')

# %%
# Analyze TotalPayBenefits of 10 richest man each Year
# Your code here
sns.barplot(data=sal.iloc[rich_man.index], y='EmployeeName', x='TotalPayBenefits', hue='Year')

# %% [markdown]
# ### You are awesome!!
